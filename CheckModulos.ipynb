# %% [markdown]
# # Apresentação:
#
# Aqui vamos testar o modulo de scraping e ver se os arquivos estão vindo adequadamente.

# %%
from dotenv import load_dotenv
import os

# %%
load_dotenv()
# Out:
# True

# %% [markdown]
# # Aquisitando dados

# %%
from resources.scraping import ScrapingClient

# %%
# Instanciando classe de scraping
scrape = ScrapingClient(os.getenv("DATA_RESOUCES"))

# Aquisitando dados
data = scrape.get_all_data()
# Out:
# [Scraping] Acessando https://www.gov.br/cgu/pt-br/acesso-a-informacao/dados-abertos/arquivos/terceirizados
# Mapeando dados...: 100%|██████████| 9/9 [00:00<00:00, 8344.11it/s]
# [Scraping] Mapeamento concluído. Anos encontrados: ['2025', '2024', '2023', '2022', '2021', '2020', '2019']
# Baixando dados...:   0%|          | 0/7 [00:06<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 5
#       2 scrape = ScrapingClient(os.getenv("DATA_RESOUCES"))
#       4 # Aquisitando dados
# ----> 5 data = scrape.get_all_data()
#
# File e:\iplanrio-desafio-data-eng\resources\scraping.py:124, in ScrapingClient.get_all_data(self)
#     122 for mes, link in meses.items():
#     123     try:
# --> 124         df = self.download_data(link, ano, mes)
#     125         dados_completos[ano][mes] = df
#     126     except Exception as e:
#
# ...

# %% [markdown]
# # Avaliando raw data

# %%
from resources.storage import MinioClient

# %%
client = MinioClient()
client.ensure_bucket_exists("terceirizados")

# %%
len(client.list_objects("terceirizados"))
# Out:
# 21
