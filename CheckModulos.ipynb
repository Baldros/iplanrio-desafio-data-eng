# %% [markdown]
# # Apresentação:
#
# Aqui vamos testar o modulo de scraping e ver se os arquivos estão vindo adequadamente.

# %%
from dotenv import load_dotenv
import os

# %%
load_dotenv()
# Out:
# True

# %% [markdown]
# # Aquisitando dados

# %%
from resources.scraping import ScrapingClient

# %%
# Instanciando classe de scraping
scrape = ScrapingClient(os.getenv("DATA_RESOUCES"))

# Aquisitando dados
data = scrape.get_all_data()

# %% [markdown]
# # Etada bronze

# %%
from resources.storage import MinioClient
from resources.dbModule import DuckDBClient
import duckdb

# %%
minio = MinioClient()
parquets = minio.list_objects("terceirizados", prefix="raw/")

# %%
for object_name in parquets:
    buffer = minio.get_object("terceirizados", object_name)
